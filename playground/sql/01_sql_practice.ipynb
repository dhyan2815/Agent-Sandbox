# %% [markdown]
# # SQL Practice

# %% [markdown]
# #### Using `JupySQL` *library* in Colab to run SQL based queries directly in the notebook
# #### Used `DuckDB` for in-memory database
# - Import Libraries

# %%
# !pip install jupysql duckdb-engine --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 22.5 MB/s eta 0:00:00

# %% [markdown]
# - Load in-memory Duck Database

# %%
# %load_ext sql
# %sql duckdb:///:memory:
# Out:
# Connecting to 'duckdb:///:memory:'

# %% [markdown]
# ## Database Table creation

# %%
# %%sql
#
# # create employee table in db
# create table EMP (
#   id INT,
#   name TEXT,
#   dept TEXT,
#   salary INT
# );
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: (duckdb.duckdb.CatalogException) Catalog Error: Table with name "EMP" already exists!
# [SQL: create table EMP (
#   id INT,
#   name TEXT,
#   dept TEXT,
#   salary INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# # insert row values into the employee table
# insert into EMP values (
#   1,
#   'Dhyan',
#   'IT',
#   15000
# );
#
# # display all columns from employee table
# select * from EMP
# Out:
# Running query in 'duckdb:///:memory:'
# +----+-------+------+--------+
# | id |  name | dept | salary |
# +----+-------+------+--------+
# | 1  | Dhyan |  IT  | 15000  |
# | 1  | Dhyan |  IT  | 15000  |
# +----+-------+------+--------+

# %% [markdown]
# ## Assignment 1
#
# #### QUESTIONS ON EMP AND DEPT TABLE:
#
# 2. WAQTD NAME OF ALL THE EMPLOYEE'S EMPLOYEE TABLE.
#
# 3. WAQTD NAME AND SALARY GIVEN TO ALL THE EMPLOYEE'S EMPLOYEE TABLE.
#
# 4. WAQTD EMPLOYEE ID AND DEPARTMENT NUMBER OF ALL THE EMPLOYEE'S EMPLOYEE TABLE.
#
# 5. WAQTD EMPLOYEE'S NAME AND HIREDATE OF ALL THE EMPLOYEE'S EMPLOYEE TABLE.
#
# 6. WAQTD DESIGNATION OF ALL THE EMPLOYEE'S EMPLOYEE TABLE.
#
# 7. WAQTD NAME, JOB AND SALARY GIVEN ALL THE EMPLOYEE'S EMPLOYEE TABLE.
#
# 8. WAQTD DANAES PRESENT IN DEPT TABLE.
#
# 9. WAQTD DANAES PRESENT IN DEPT TABLE.
#
# 10. WAQTD DANAES AND LOCATION PRESENT IN DEPT TABLE.

# %%
# TO EXECUTE THE ABOVE ASSIGNMENT QUERIES BELOW IS THE DB COLUMNS AND ITS VALUES CREATION;
# %%sql

CREATE TABLE DEPT (
    DEPTNO   NUMBER(2) PRIMARY KEY,
    DNAME    VARCHAR2(14),
    LOC      VARCHAR2(13)
);

INSERT INTO DEPT VALUES (10, 'ACCOUNTING', 'NEW YORK');
INSERT INTO DEPT VALUES (20, 'RESEARCH',   'DALLAS');
INSERT INTO DEPT VALUES (30, 'SALES',      'CHICAGO');
INSERT INTO DEPT VALUES (40, 'OPERATIONS', 'BOSTON');
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: (duckdb.duckdb.CatalogException) Catalog Error: Type with name NUMBER does not exist!
# [SQL: CREATE TABLE DEPT (
#     DEPTNO   NUMBER(2) PRIMARY KEY,
#     DNAME    VARCHAR2(14),
#     LOC      VARCHAR2(13)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# CREATE TABLE EMP (
#     EMPNO    NUMBER(4) PRIMARY KEY,
#     ENAME    VARCHAR2(10),
#     JOB      VARCHAR2(9),
#     MGR      NUMBER(4),
#     HIREDATE DATE,
#     SAL      NUMBER(7,2),
#     COMM     NUMBER(7,2),
#     DEPTNO   NUMBER(2),
#     FOREIGN KEY (DEPTNO) REFERENCES DEPT(DEPTNO)
# );
#
# INSERT INTO EMP VALUES (7369, 'SMITH',  'CLERK',     7902, TO_DATE('17-DEC-1980','DD-MON-YYYY'), 800,  NULL, 20);
# INSERT INTO EMP VALUES (7499, 'ALLEN',  'SALESMAN',  7698, TO_DATE('20-FEB-1981','DD-MON-YYYY'), 1600, 300,  30);
# INSERT INTO EMP VALUES (7521, 'WARD',   'SALESMAN',  7698, TO_DATE('22-FEB-1981','DD-MON-YYYY'), 1250, 500,  30);
# INSERT INTO EMP VALUES (7566, 'JONES',  'MANAGER',   7839, TO_DATE('02-APR-1981','DD-MON-YYYY'), 2975, NULL, 20);
# INSERT INTO EMP VALUES (7654, 'MARTIN', 'SALESMAN',  7698, TO_DATE('28-SEP-1981','DD-MON-YYYY'), 1250, 1400, 30);
# INSERT INTO EMP VALUES (7698, 'BLAKE',  'MANAGER',   7839, TO_DATE('01-MAY-1981','DD-MON-YYYY'), 2850, NULL, 30);
# INSERT INTO EMP VALUES (7782, 'CLARK',  'MANAGER',   7839, TO_DATE('09-JUN-1981','DD-MON-YYYY'), 2450, NULL, 10);
# INSERT INTO EMP VALUES (7788, 'SCOTT',  'ANALYST',   7566, TO_DATE('19-APR-1987','DD-MON-YYYY'), 3000, NULL, 20);
# INSERT INTO EMP VALUES (7839, 'KING',   'PRESIDENT', NULL, TO_DATE('17-NOV-1981','DD-MON-YYYY'), 5000, NULL, 10);
# INSERT INTO EMP VALUES (7844, 'TURNER', 'SALESMAN',  7698, TO_DATE('08-SEP-1981','DD-MON-YYYY'), 1500, 0,   30);
# INSERT INTO EMP VALUES (7876, 'ADAMS',  'CLERK',     7788, TO_DATE('23-MAY-1987','DD-MON-YYYY'), 1100, NULL, 20);
# INSERT INTO EMP VALUES (7900, 'JAMES',  'CLERK',     7698, TO_DATE('03-DEC-1981','DD-MON-YYYY'), 950,  NULL, 30);
# INSERT INTO EMP VALUES (7902, 'FORD',   'ANALYST',   7566, TO_DATE('03-DEC-1981','DD-MON-YYYY'), 3000, NULL, 20);
# INSERT INTO EMP VALUES (7934, 'MILLER', 'CLERK',     7782, TO_DATE('23-JAN-1982','DD-MON-YYYY'), 1300, NULL, 10);
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: (duckdb.duckdb.CatalogException) Catalog Error: Type with name NUMBER does not exist!
# [SQL: CREATE TABLE EMP (
#     EMPNO    NUMBER(4) PRIMARY KEY,
#     ENAME    VARCHAR2(10),
#     JOB      VARCHAR2(9),
#     MGR      NUMBER(4),
#     HIREDATE DATE,
#     SAL      NUMBER(7,2),
#     COMM     NUMBER(7,2),
#     DEPTNO   NUMBER(2),
#     FOREIGN KEY (DEPTNO) REFERENCES DEPT(DEPTNO)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)
